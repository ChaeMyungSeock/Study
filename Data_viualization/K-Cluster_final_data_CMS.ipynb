# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans,DBSCAN
from sklearn.preprocessing import scale,MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples, silhouette_score
import seaborn as sns


# %matplotlib inline

# %%
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/My Drive/data/final_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#       Height  Weight        BMI  ...  Diagnosis_7  Diagnosis_8  Diagnosis_9
# 0      161.6    57.8  22.133247  ...            0            0            0
# 1      159.7    63.1  24.741130  ...            0            0            0
# 2      178.4    64.3  20.203252  ...            0            0            0
# 3      168.7    74.3  26.107101  ...            0            0            0
# 4      161.7    51.7  19.772906  ...            0            0            0
# ...      ...     ...        ...  ...          ...          ...          ...
# 1554   173.0    88.0  29.402920  ...            0            0            0
# 1555   156.0    64.0  26.298488  ...            0            0            0
# 1556   161.0    86.0  33.177732  ...            0            0            0
# 1557   156.0    64.0  26.298488  ...            0            0            0
# 1558   169.0    63.0  22.058051  ...            0            0            0
#
# [1559 rows x 78 columns]

# %%
data = data.drop(columns=["BMI", "Age","VNG(%)","SN","GA","F_GA","S_GA","S_PCI","PCI","F_PCI","S_Cadence",	"S_Stride_L",	"S_Stride_R",	"S_Step_L",	"S_Step_R",	"S_SS_L",	"S_SS_R",	"S_DS_L",	"S_DS_R",	"S_Time_Toe_L",	"S_Time_Toe_R",	"S_ROM_IE_L",	"S_ROM_IE_R",	"S_ROM_DP_L",	"S_ROM_DP_R", "S_ROM_AA_L",	"S_ROM_AA_R", "F_Cadence",	"F_Stride_L",	"F_Stride_R",	"F_Step_L",	"F_Step_R",	"F_SS_L",	"F_SS_R",	"F_DS_L",	"F_DS_R",	"F_Time_Toe_L",	"F_Time_Toe_R",	"F_ROM_IE_L",	"F_ROM_IE_R",	"F_ROM_DP_L",	"F_ROM_DP_R",	"F_ROM_AA_L",	"F_ROM_AA_R"	 ])
data = data.dropna()
data
# "Cadence","Stride_L","Stride_R", "Step_L",	"Step_R",	"SS_L",	"SS_R",	"DS_L",	"DS_R",	"Time_Toe_L",	"Time_Toe_R",	"ROM_IE_L",	"ROM_IE_R",	"ROM_DP_L",	"ROM_DP_R",	"ROM_AA_L",	"ROM_AA_R"
# Out:
#       Height  Weight  N_Speed  ...  Diagnosis_7  Diagnosis_8  Diagnosis_9
# 0      161.6    57.8      3.6  ...            0            0            0
# 1      159.7    63.1      4.5  ...            0            0            0
# 2      178.4    64.3      3.6  ...            0            0            0
# 3      168.7    74.3      3.0  ...            0            0            0
# 4      161.7    51.7      4.0  ...            0            0            0
# ...      ...     ...      ...  ...          ...          ...          ...
# 1554   173.0    88.0      5.1  ...            0            0            0
# 1555   156.0    64.0      6.0  ...            0            0            0
# 1556   161.0    86.0      4.5  ...            0            0            0
# 1557   156.0    64.0      4.5  ...            0            0            0
# 1558   169.0    63.0      4.5  ...            0            0            0
#
# [1465 rows x 34 columns]

# %%
scaler = MinMaxScaler()

# %%
data_col = data.columns

# %%
data.columns
# Out:
# Index(['Height', 'Weight', 'N_Speed', 'Cadence', 'Stride_L', 'Stride_R',
#        'Step_L', 'Step_R', 'SS_L', 'SS_R', 'DS_L', 'DS_R', 'Time_Toe_L',
#        'Time_Toe_R', 'ROM_IE_L', 'ROM_IE_R', 'ROM_DP_L', 'ROM_DP_R',
#        'ROM_AA_L', 'ROM_AA_R', 'S_Speed', 'F_Speed', 'class', 'Gender_F',
#        'Gender_M', 'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Diagnosis_6', 'Diagnosis_7', 'Diagnosis_8',
#        'Diagnosis_9'],
#       dtype='object')

# %%
y= scaler.fit_transform(data)

# %%
y = pd.DataFrame(y,columns=data_col)

# %%
# from sklearn.pipeline import make_pipeline

# model = DBSCAN(eps=0.5,min_samples=8)
# model = make_pipeline(scaler, model)

# predict = pd.DataFrame(model.fit_predict(y))
# predict.columns=['predict']

r=y

# %%
r
# Out:
#         Height    Weight   N_Speed  ...  Diagnosis_7  Diagnosis_8  Diagnosis_9
# 0     0.469159  0.181695  0.409836  ...          0.0          0.0          0.0
# 1     0.433645  0.217627  0.557377  ...          0.0          0.0          0.0
# 2     0.783178  0.225763  0.409836  ...          0.0          0.0          0.0
# 3     0.601869  0.293559  0.311475  ...          0.0          0.0          0.0
# 4     0.471028  0.140339  0.475410  ...          0.0          0.0          0.0
# ...        ...       ...       ...  ...          ...          ...          ...
# 1460  0.682243  0.386441  0.655738  ...          0.0          0.0          0.0
# 1461  0.364486  0.223729  0.803279  ...          0.0          0.0          0.0
# 1462  0.457944  0.372881  0.557377  ...          0.0          0.0          0.0
# 1463  0.364486  0.223729  0.557377  ...          0.0          0.0          0.0
# 1464  0.607477  0.216949  0.557377  ...          0.0          0.0          0.0
#
# ...

# %%
from itertools import combinations
string = combinations(y.columns,3)
a = list(string)

# %%
len(a)
# Out:
# 5984

# %%
a[0][0]
# Out:
# 'Height'

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# for i in range(len(a[2000:4000])):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['predict']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# # c=['r['predict']']

# %%
# !pip install ipympl

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(0,300):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# # c=['r['predict']']

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(300,500):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(500,700):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
# scatter plot

string = y.columns
for i in range(0,100):
  fig = plt.figure( figsize=(6,6))
  ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
  ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
  ax.set_xlabel(a[i][0])
  ax.set_ylabel(a[i][1])
  ax.set_zlabel(a[i][2])
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from mpl_toolkits.mplot3d import Axes3D
# scatter plot

string = y.columns
for i in range(100,200):
  fig = plt.figure( figsize=(6,6))
  ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
  ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
  ax.set_xlabel(a[i][0])
  ax.set_ylabel(a[i][1])
  ax.set_zlabel(a[i][2])
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from mpl_toolkits.mplot3d import Axes3D
# scatter plot

string = y.columns
for i in range(200,300):
  fig = plt.figure( figsize=(6,6))
  ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
  ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
  ax.set_xlabel(a[i][0])
  ax.set_ylabel(a[i][1])
  ax.set_zlabel(a[i][2])
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(300,400):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(2100,2400):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(2400,2700):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(2700,3000):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(3000,3300):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(3300,3600):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(3600,3900):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(3900,4200):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(4200,4500):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(4500,4800):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # scatter plot

# string = y.columns
# for i in range(4800,5100):
#   fig = plt.figure( figsize=(6,6))
#   ax = Axes3D(fig, rect=[0, 0, 2, 2], elev=48, azim=134)
#   ax.scatter(r[a[i][0]],r[a[i][1]],r[a[i][2]],c=[r['class']],alpha=0.5)
#   ax.set_xlabel(a[i][0])
#   ax.set_ylabel(a[i][1])
#   ax.set_zlabel(a[i][2])
#   plt.show()
